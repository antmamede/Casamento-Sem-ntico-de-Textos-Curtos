# %% [markdown]
# # Importando Pacotes

# %%
import os
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import nltk
import strsimpy
import numpy as np
from strsimpy.normalized_levenshtein import NormalizedLevenshtein
from strsimpy.jaro_winkler import JaroWinkler
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models import KeyedVectors

# %% [markdown]
# # Paths

# %%
path_bases = "C:\\Users\\aamma\\OneDrive\\ENCE\\TCC\\REFAZENDO EXPERIMENTO\\Bases"
path_embeddings = "C:\\Users\\aamma\\OneDrive\\ENCE\\TCC\\REFAZENDO EXPERIMENTO\\Embeddings"
path_resultados = "C:\\Users\\aamma\\OneDrive\\ENCE\\TCC\\REFAZENDO EXPERIMENTO\\Resultados"

# %% [markdown]
# # Leitura de Bases

# %%
os.chdir(path_bases)
descricoes_pof = pd.read_excel("Descricoes_POF_TodosSinonimos.xlsx")
descricoes_snipc = pd.read_excel("Descricoes_SNIPC_TodosSinonimos.xlsx")
descricoes_pof = descricoes_pof.values.tolist() # Converte dataframe para lista de listas
descricoes_snipc = descricoes_snipc.values.tolist() # Coverte dataframe para lista de listas
descricoes_pof = [item for sublist in descricoes_pof for item in sublist] # Converte lista de listas para lista
descricoes_snipc = [item for sublist in descricoes_snipc for item in sublist] # Converte lista de listas para lista

# %% [markdown]
# # Criando Matrizes de Similaridade

# %%
## Levenshtein
df_levenshtein = np.zeros((len(descricoes_pof), len(descricoes_snipc)))
df_levenshtein = pd.DataFrame(df_levenshtein, columns = descricoes_snipc,
index = descricoes_pof)

## Jaro
df_jaro = np.zeros((len(descricoes_pof), len(descricoes_snipc)))
df_jaro = pd.DataFrame(df_jaro, columns = descricoes_snipc,
index = descricoes_pof)

## Jaccard
df_jaccard = np.zeros((len(descricoes_pof), len(descricoes_snipc)))
df_jaccard = pd.DataFrame(df_jaccard, columns = descricoes_snipc,
index = descricoes_pof)

## TF-IDF
df_tfidf = np.zeros((len(descricoes_pof), len(descricoes_snipc)))
df_tfidf = pd.DataFrame(df_tfidf, columns = descricoes_snipc,
index = descricoes_pof)

## Word2Vec
df_word2vec_soma = np.zeros((len(descricoes_pof), len(descricoes_snipc)))
df_word2vec_soma = pd.DataFrame(df_word2vec_soma, columns = descricoes_snipc,
index = descricoes_pof)
df_word2vec_media = np.zeros((len(descricoes_pof), len(descricoes_snipc)))
df_word2vec_media = pd.DataFrame(df_word2vec_media, columns = descricoes_snipc,
index = descricoes_pof)

# %% [markdown]
# # Calculando Similaridade

# %% [markdown]
# ## Levenshtein

# %%
levenshtein = NormalizedLevenshtein()
contador = 0
for palavra_pof in df_levenshtein.index:
    for palavra_snipc in df_levenshtein.columns:
        df_levenshtein.at[palavra_pof, palavra_snipc] = levenshtein.similarity(palavra_pof, palavra_snipc)
    contador = contador + 1
    if contador % 700 == 0 or contador == 3305:
        print(contador / df_levenshtein.shape[0] * 100, "%")
# Out:
# 21.18003025718608 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       3 for palavra_pof in df_levenshtein.index:
#       4     for palavra_snipc in df_levenshtein.columns:
# ----> 5         df_levenshtein.at[palavra_pof, palavra_snipc] = levenshtein.similarity(palavra_pof, palavra_snipc)
#       6     contador = contador + 1
#       7     if contador % 700 == 0 or contador == 3305:
#
# File E:\miniconda3\envs\tcc\lib\site-packages\strsimpy\normalized_levenshtein.py:44, in NormalizedLevenshtein.similarity(self, s0, s1)
#      43 def similarity(self, s0, s1):
# ---> 44     return 1.0 - self.distance(s0, s1)
#
# File E:\miniconda3\envs\tcc\lib\site-packages\strsimpy\normalized_levenshtein.py:41, in NormalizedLevenshtein.distance(self, s0, s1)
#      39 if m_len == 0:
#      40     return 0.0
# ---> 41 return self.levenshtein.distance(s0, s1) / m_len
#
# File E:\miniconda3\envs\tcc\lib\site-packages\strsimpy\levenshtein.py:50, in Levenshtein.distance(self, s0, s1)
#      48         if s0[i] == s1[j]:
#      49             cost = 0
# ---> 50         v1[j + 1] = min(v1[j] + 1, v0[j + 1] + 1, v0[j] + cost)
#      51     v0, v1 = v1, v0
#      53 return v0[len(s1)]
#
# KeyboardInterrupt:

# %%
path_resultados = "C:\\Users\\aamma\\OneDrive\\ENCE\\TCC\\REFAZENDO EXPERIMENTO\\Resultados"
os.chdir(path_resultados)
df_levenshtein.to_excel("Levenshtein_TodosSinonimos_MS.xlsx")

# %% [markdown]
# ## Jaro

# %%
jaro = JaroWinkler()
contador = 0
for palavra_pof in df_jaro.index:
    for palavra_snipc in df_jaro.columns:
        df_jaro.at[palavra_pof, palavra_snipc] = jaro.similarity(palavra_pof, palavra_snipc)
    contador = contador + 1
    if contador % 700 == 0 or contador == 3305:
        print(contador / df_jaro.shape[0] * 100, "%")
# Out:
# 21.18003025718608 %
# 42.36006051437216 %
# 63.54009077155824 %
# 84.72012102874432 %
# 100.0 %

# %%
os.chdir(path_resultados)
df_jaro.to_excel("Jaro_TodosSinonimos_MS.xlsx")

# %% [markdown]
# ## Jaccard

# %%
contador = 0
for palavra_pof in df_jaccard.index:
    for palavra_snipc in df_jaccard.columns:
        tok_pof = set(palavra_pof.split())
        tok_snipc = set(palavra_snipc.split())
        numerador = tok_pof & tok_snipc
        denominador = tok_pof | tok_snipc
        df_jaccard.at[palavra_pof, palavra_snipc] = len(numerador) / len(denominador)
    contador = contador + 1
    if contador % 700 == 0 or contador == 3305:
        print(contador / df_jaccard.shape[0] * 100, "%")
# Out:
# 21.18003025718608 %
# 42.36006051437216 %
# 63.54009077155824 %
# 84.72012102874432 %
# 100.0 %

# %%
os.chdir(path_resultados)
df_jaccard.to_excel("Jaccard_TodosSinonimos_MS.xlsx")

# %% [markdown]
# ## TF-IDF

# %%
vectorizer = TfidfVectorizer()

# Juntando Todas as Descrições e Removendo duplicatas
todas_descricoes = descricoes_pof + descricoes_snipc
todas_descricoes = pd.Series(todas_descricoes).drop_duplicates().to_list()

# Calculando valores TF-IDF
tfidf_matrix = vectorizer.fit_transform(todas_descricoes)

# Transformando Matriz TF-IDF em DF
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), index=todas_descricoes, columns=vectorizer.get_feature_names_out())

# Filtrando por pesquisas
tfidf_snipc = tfidf_df.filter(items = descricoes_snipc, axis = 0)
tfidf_pof = tfidf_df.filter(items = descricoes_pof, axis = 0)

## Calculando Cosseno e transformando em DF
cosine_sim = cosine_similarity(tfidf_pof, tfidf_snipc)
df_tfidf = pd.DataFrame(cosine_sim, index = descricoes_pof, columns = descricoes_snipc)

# %%
os.chdir(path_resultados)
df_tfidf.to_excel("TFIDF_TodosSinonimos_MS.xlsx")

# %% [markdown]
# # Word2vec

# %%
os.chdir(path_embeddings)
os.getcwd()
model = KeyedVectors.load_word2vec_format("skip_s300.txt")

# %%
os.chdir(path_bases)
tokens_all = pd.read_excel("Tokens_All_TodosSinonimos.xlsx")
tokens_all = tokens_all.values.tolist()
tokens_all = [item for sublist in tokens_all for item in sublist]
vocab_set = set(model.index_to_key)
keep_set = set(tokens_all)
drop_set = vocab_set - keep_set
for word in drop_set:
    del model.key_to_index[word]

# %%
tokens_nc = pd.read_excel("Tokens_All_NC_TodosSinonimos.xlsx")
tokens_nc = tokens_nc.values.tolist()
tokens_nc = [item for sublist in tokens_nc for item in sublist]

# %%
tokens_nc
# Out:
# ['cabotian',
#  'caxaco',
#  'moganga',
#  'moganguice',
#  'mogiganga',
#  'monada',
#  'moquenquice',
#  'maratimba',
#  'pioca',
#  'restingueiro',
#  'tapiocano',
#  'absorbente',
#  'feminal',
#  'femíneo',
#  'fêmeo',
#  'avizinhação',
#  'adiáforo',
#  'suplementário',
#  'catamênio',
#  'circunstanciativo',
#  'minudencioso',
#  'legente',
#  'celulado',
#  'celulífero',
#  'celuloso',
#  'nosocômico',
#  'blandície',
#  'melifluidade',
#  'indefinito',
#  'edulcorativo',
#  'pousadia',
#  'abrigadoiro',
#  'abrigadouro',
#  'gabinardo',
#  'ameninado',
#  'menineiro',
#  'meninil',
#  'apendente',
#  'esgotadura',
#  'escoadoiro',
#  'anorgânico',
#  'anhanho',
#  'apancadado',
#  'apancado',
#  'bajoujo',
#  'bucuva',
#  'inhenho',
#  'maninelo',
#  'acúmen',
#  'picaroto',
#  'desalagar',
#  'desempachar',
#  'desentaipar',
#  'desentravar',
#  'desestorvar',
#  'laxar',
#  'ajiru',
#  'guajuru',
#  'uajuru',
#  'tranqueta',
#  'átlas',
#  'adustível',
#  'abstergência',
#  'abstersão',
#  'alimpadura',
#  'alimpamento',
#  'limpamento',
#  'mundícia',
#  'mundície',
#  'abastamento',
#  'amaestrar',
#  'aviventação',
#  'cápreo',
#  'caprum',
#  'egofônico',
#  'decertar',
#  'gladiar',
#  'refregar',
#  'pesa-papéis',
#  'cafife',
#  'caiporice',
#  'calistismo',
#  'alparcata',
#  'alpergata',
#  'imódico',
#  'abarbarado',
#  'alentoso',
#  'corajudo',
#  'desmedroso',
#  'coruta',
#  'fretagem',
#  'esteado',
#  'apedrado',
#  'circundamento',
#  'aiaia',
#  'encerebração',
#  'renhimento',
#  'albente',
#  'alvejador',
#  'branquejante',
#  'levadiço',
#  'amplificante',
#  'aumentante',
#  'enágua',
#  'animante',
#  'vivedoiro',
#  'vivedouro',
#  'merthiolathe',
#  'acepilhadura',
#  'riscadura',
#  'riscamento',
#  'pegadoiro',
#  'pegadouro',
#  'ensurdecência',
#  'surdeza',
#  'aquátil',
#  'aqüígeno',
#  'áqüeo',
#  'adquirimento',
#  'alcançamento',
#  'bafego',
#  'abditório',
#  'rípio',
#  'aboiz',
#  'arriosca',
#  'embusteirice',
#  'embustice',
#  'velhacagem',
#  'escanado',
#  'dessossego',
#  'ajeitação',
#  'ajeitamento',
#  'rematação',
#  'cauíla',
#  'cauíra',
#  'manicurto',
#  'socancra',
#  'coscoro',
#  'cuxa',
#  'acepilhado',
#  'bem-ensinado',
#  'açacalado',
#  'acicalado',
#  'bispote',
#  'mijadeiro',
#  'repleno',
#  'afano',
#  'volibol',
#  'dominni',
#  'ajudadoiro',
#  'ajudadouro',
#  'mortório',
#  'mortualha',
#  'mortuório',
#  'avoador',
#  'abatocado',
#  'abotocado',
#  'arvoado',
#  'azoeirado',
#  'azoratado',
#  'soalhado',
#  'babadoiro',
#  'babadouro',
#  'recém-nado',
#  'rescaldeiro',
#  'drope',
#  'goma-de-mascar',
#  'defluir',
#  'acarrear',
#  'chincar',
#  'adereçar',
#  'sobrescritar',
#  'extrapassar',
#  'sobreexceder',
#  'incutir-se',
#  'infundir-se',
#  'ajoeirar',
#  'outar',
#  'sengar',
#  'sessar',
#  'sururucar',
#  'efundir-se',
#  'ensementar',
#  'inçar',
#  'propalar-se',
#  'desembuçar',
#  'desencerrar',
#  'dessoterrar',
#  'palrear',
#  'patentizar',
#  'despassar',
#  'pervagar',
#  'surcar',
#  'transcursar',
#  'esfregalho',
#  'balneatório',
#  'setial',
#  'baraticida',
#  'tijupar',
#  'guardamento',
#  'abodegado',
#  'balordo',
#  'bodoso',
#  'desasseado',
#  'embodegado',
#  'espurco',
#  'lixento',
#  'lixoso',
#  'abana-moscas',
#  'quiquiriqui',
#  'bem-soante',
#  'bem-sonante',
#  'cadencioso',
#  'mélico',
#  'monteada',
#  'veação',
#  'varejamento',
#  'reboldrosa',
#  'zagunchada',
#  'zargunchada',
#  'abalroação',
#  'encontroada',
#  'bauleto',
#  'beribá',
#  'uricungo',
#  'berregador',
#  'berregante',
#  'clamador',
#  'bicama',
#  'triliche',
#  'humildoso',
#  'amenoso',
#  'dúlcido',
#  'melífico',
#  'afetível',
#  'aprazenteiro',
#  'libente',
#  'gulosice',
#  'gulosina',
#  'recheadura',
#  'munhecaço',
#  'brajola',
#  'arrepelação',
#  'arrepelada',
#  'escarapela',
#  'brotadura',
#  'ossaria',
#  'sarabatana',
#  'multiponteado',
#  'multipontuado',
#  'salpintado',
#  'anteguarda',
#  'manadeira',
#  'manadeiro',
#  'cadastragem',
#  'camparesco',
#  'campesinho',
#  'retalhação',
#  'abridela',
#  'abalançamento',
#  'redoiça',
#  'redouça',
#  'retoiça',
#  'retouça',
#  'meneamento',
#  'acômodo',
#  'autopropulsante',
#  'autopropulsor',
#  'livreta',
#  'dissolúvel',
#  'dissolvível',
#  'cristáleo',
#  'incorruto',
#  'columbino',
#  'desenxovalhado',
#  'inconspurcado',
#  'perficiente',
#  'ádipe',
#  'ádipo',
#  'segureza',
#  'porfioso',
#  'embatumar',
#  'recamar',
#  'arroupar',
#  'enroupar',
#  'gasalhar',
#  'acoutar',
#  'anteparar',
#  'embarricar',
#  'acafelar',
#  'amofumbar',
#  'assolapar',
#  'capear',
#  'colorar',
#  'colorear',
#  'encangotar',
#  'indutar',
#  'embrumar',
#  'encarrancar',
#  'enuviar',
#  'nevoar',
#  'sombrejar',
#  'turvejar',
#  'exsolver',
#  'persolver',
#  'volteiro',
#  'voltívolo',
#  'porta-cartas',
#  'fenecido',
#  'márcido',
#  'desempapado',
#  'sarrabulhada',
#  'comprobante',
#  'zé-da-véstia',
#  'xicaca',
#  'chanura',
#  'agrisalhado',
#  'arruçado',
#  'lacticolor',
#  'lactíneo',
#  'láteo',
#  'grandevo',
#  'arcaístico',
#  'insueto',
#  'velhustro',
#  'trigueiro-claro',
#  'bacento',
#  'baciado',
#  'vidrento',
#  'farrusquento',
#  'sapateta',
#  'encartonado',
#  'churdo',
#  'lidroso',
#  'ludrento',
#  'ludro',
#  'ludroso',
#  'perraria',
#  'remoela',
#  'adereçamento',
#  'aformosentamento',
#  'ataviamento',
#  'enfeitamento',
#  'teada',
#  'tapação',
#  'tapadura',
#  'ensombro',
#  'adjeto',
#  'convizinho',
#  'propínquo',
#  'sustenta-seios',
#  'basteado',
#  'advertimento',
#  'aquentador',
#  'desconvizinho',
#  'piscicaptura',
#  'alvitana',
#  'esparavel',
#  'zangarelha',
#  'zangarelho',
#  'generante',
#  'ocasionador',
#  'borbulhão',
#  'gorgolão',
#  'gorgolhão',
#  'liquidificante',
#  'liqüidificante',
#  'sobreestar',
#  'cabrocar',
#  'cabrucar',
#  'foiçar',
#  'fouçar',
#  'ajarretar',
#  'derriscar',
#  'destroncar',
#  'detruncar',
#  'estaquear',
#  'tronchar',
#  'aguarentar',
#  'bromar',
#  'abarrancar',
#  'abarreirar',
#  'abarrocar',
#  'apejar',
#  'atrancar',
#  'atranqueirar',
#  'atrapachar',
#  'empachar',
#  'empancar',
#  'amodelar',
#  'eqüivaler',
#  'interprender',
#  'interpresar',
#  'parentar',
#  'empenhorar-se',
#  'desencardir',
#  'detergir',
#  'escasquear',
#  'abluir',
#  'dealvar',
#  'desenxovalhar',
#  'emundar',
#  'escoriar',
#  'escorificar',
#  'mundificar',
#  'perlavar',
#  'desempapar',
#  'desencharcar',
#  'desensopar',
#  'dessecar',
#  'desumedecer',
#  'amurchecer',
#  'engelhar',
#  'murchecer',
#  'atristar',
#  'desflorescer',
#  'desflorir',
#  'desverdecer',
#  'enfenecer',
#  'exsicar',
#  'ressicar',
#  'resmoer',
#  'alanhar',
#  'aplastar',
#  'esbofar',
#  'fadigar',
#  'malaxar',
#  'atroçoar',
#  'cominuir',
#  'despeçar',
#  'migalhar',
#  'migar',
#  'retrilhar',
#  'sanfoninar',
#  'mundificante',
#  'mundificativo',
#  'apurativo',
#  'purificativo',
#  'roçadoura',
#  'sovadeira',
#  'ventilante',
#  'oftalmólogo',
#  'psiquiatrista',
#  'psiquiatro',
#  'adnumeração',
#  'diz-que-me-diz-que',
#  'nhenhenhén',
#  'runrum',
#  'precação',
#  'embriagamento',
#  'vinolência',
#  'abrasamento',
#  'afogueamento',
#  'tingidura',
#  'consueto',
#  'sólito',
#  'corretório',
#  'aparação',
#  'podadura',
#  'cissura',
#  'cortil',
#  'acitara',
#  'vigiante',
#  'perguntante',
#  'abiúdo',
#  'intrometidiço',
#  'abarcamento',
#  'vasteza',
#  'graduamento',
#  'anteprimeiro',
#  'amoderar',
#  'adorativo',
#  'robustidão',
#  'valorosidade',
#  'adminicular',
#  'adjutorar',
#  'segundar',
#  'auxiliante',
#  'auxiliário',
#  'adjutor',
#  'peladura',
#  'achatadela',
#  'achatadura',
#  'amolgação',
#  'amolgadura',
#  'antidepressante',
#  'descarbonizante',
#  'anti-sepsiador',
#  'desinfetador',
#  'antibrômico',
#  'diurnal',
#  'discrime',
#  'discrímen',
#  'dividimento',
#  'contristação',
#  'apuamento',
#  'analgético',
#  'análgico',
#  'antipíreo',
#  'drageado',
#  'entroixo',
#  'entrouxo',
#  'recamadura',
#  'recamo',
#  'requifife',
#  'carro-guincho',
#  'acafeladura',
#  'acafelamento',
#  'rebocadura',
#  'antiemetico',
#  'regurgitamento',
#  'entreforro',
#  'involutório',
#  'relheira',
#  'relheiro',
#  'rieira',
#  'refalsamento',
#  'tijolaria',
#  'corta-papel',
#  'espreguiçador',
#  'preguiceiro',
#  'apetitar',
#  'desacobardar',
#  'desacovardar',
#  'desatemorizar',
#  'afoutar',
#  'desmodorrar',
#  'esperançar',
#  'alactamento',
#  'boicera',
#  'boucera',
#  'excreto',
#  'escorralho',
#  'fundagem',
#  'digresso',
#  'facalhaz',
#  'fagotini',
#  'bem-afortunado',
#  'bem-ditoso',
#  'bem-fadado',
#  'fortunoso',
#  'arraiado',
#  'borrachice',
#  'zangurriana',
#  'zangurrina',
#  'lampana',
#  'potoca',
#  'fatigamento',
#  'fixativo',
#  'despresumido',
#  'despresunçoso',
#  'insito',
#  'inartificioso',
#  'floreiro',
#  'porta-flores',
#  'enfreamento',
#  'refreio',
#  'sofreamento',
#  'fogotini',
#  'arroubar',
#  'agudar',
#  'açodar',
#  'afalcoar',
#  'aferroar',
#  'afervorar',
#  'afoguear',
#  'aguilhar',
#  'apicaçar',
#  'cotovelar',
#  'escandescer',
#  'esfoguear',
#  'folhento',
#  'folhudo',
#  'foliforme',
#  'folhame',
#  'folharia',
#  'bochornal',
#  'calmoroso',
#  'vazadura',
#  'acirrante',
#  'ecfrático',
#  'estimuloso',
#  'insaciedade',
#  'fumista',
#  'pitador',
#  'retratador',
#  'sobpé',
#  'acapachado',
#  'arrefeçado',
#  'desentonado',
#  'desgraduado',
#  'alicaído',
#  'amarasmado',
#  'amarasmeado',
#  'desacorçoado',
#  'desacoroçoado',
#  'descorajado',
#  'avexado',
#  'cabiscaído',
#  'afracado',
#  'amarroado',
#  'anemiado',
#  'descangotado',
#  'dessangrado',
#  'elanguescido',
#  'invulnerado',
#  'carretagem',
#  'petema',
#  'petima',
#  'esfarpado',
#  'aguçadeira',
#  'amoladeira',
#  'almargeal',
#  'assopradela',
#  'assopramento',
#  'nugativo',
#  'nugatório',
#  'gevral',
#  'grampador',
#  'albergamento',
#  'arrancho',
#  'pernoute',
#  'aboletamento',
#  'afiguração',
#  'inficionação',
#  'ignificação',
#  'efetuoso',
#  'antemurado',
#  'inesitante',
#  'rescrição',
#  'passadeiro',
#  'mexerufada',
#  'paparrotada',
#  'paparrotagem',
#  'untadura',
#  'untura',
#  'quatro-paus',
#  'encondensado',
#  'breviloqüente',
#  'compendioso',
#  'desenatado',
#  'enviçado',
#  'tocamento',
#  'personativo',
#  'alimpador',
#  'mundanário',
#  'terrento',
#  'terrulento',
#  'carpidor',
#  'mondador',
#  'varejadura',
#  'brilhantar',
#  'aformosar',
#  'aformosentar',
#  'ajaezar',
#  'alfaiar',
#  'amoldurar',
#  'aparamentar',
#  'assazoar',
#  'assazonar',
#  'embrincar',
#  'emoldar',
#  'esterqueiro',
#  'podredouro',
#  'volutabro',
#  'abonamento',
#  'fiadoria',
#  'abaixa-luz',
#  'lucivelo',
#  'lucivéu',
#  'pára-luz',
#  'refletidor',
#  'tapa-luz',
#  'alampadário',
#  'lumeeira',
#  'esplendecência',
#  'perfulgência',
#  'resplendência',
#  'carlequim',
#  'maiozinho',
#  'subimento',
#  'graceta',
#  'picueta',
#  'picuetada',
#  'alvanéu',
#  'alvenel',
#  'alvener',
#  'anaçar',
#  'desborcelar',
#  'desborcinar',
#  'esborcelar',
#  'esborcinar',
#  'esbotenar',
#  'esbrucinar',
#  'garrir',
#  'tintinabular',
#  'titilar',
#  'apalear',
#  'aporrear',
#  'aporretar',
#  'delombar',
#  'derrear',
#  'derrengar',
#  'desasar',
#  'descadeirar',
#  'deslombar',
#  'desquadrilhar',
#  'escadeirar',
#  'escambichar',
#  'esquadrilhar',
#  'martelejar',
#  'mecanografar',
#  'acravar',
#  'afincar',
#  'enfincar',
#  'agadanhar',
#  'arrapinar',
#  'bifar',
#  'desvalijar',
#  'escamotar',
#  'escorchar',
#  'gatear',
#  'gatunar',
#  'gatunhar',
#  'ladroar',
#  'larapiar',
#  'balroar',
#  'apiloar',
#  'apisoar',
#  'pisoar',
#  'socalcar',
#  'pujar',
#  'afrouxelado',
#  'flegmático',
#  'lerdeador',
#  'alombado',
#  'bambalhão',
#  'engrunhido',
#  'manzanza',
#  'mazanza',
#  'napeiro',
#  'preguicento',
#  'froixo',
#  'tutriz',
#  'valhacoito',
#  'capeleti',
#  'semipronta',
#  'pregagem',
#  'calafetamento',
#  'tapigo',
#  'impedição',
#  'lapidagem',
#  'polidura',
#  'raviole',
#  'rotolone',
#  'estronca',
#  'curatriz',
#  'mijãozinho',
#  'moedela',
#  'admistão',
#  'misturação',
#  'inevidência',
#  'permistão',
#  'sagum',
#  'multiervas',
#  'nibis',
#  'berganha',
#  'omeleteira',
#  'ourinol',
#  '15',
#  'distraimento',
#  'diversório',
#  'acarretadura',
#  'carreação',
#  'concernência',
#  'telefonada',
#  'polenguinho',
#  'multigrãos',
#  'partimento',
#  'esborôo',
#  'arrampado',
#  'perambulagem',
#  'vagueação',
#  'encavilhado',
#  'marroada',
#  'cachamorrada',
#  'guarda-chuvada',
#  'abrote',
#  'anujá',
#  'abadiva',
#  'caicanha',
#  'corcoroca',
#  'auricolor',
#  'aurífico',
#  'auriginoso',
#  'críseo',
#  'polmão',
#  'guaivira',
#  'galanteado',
#  'amoriscado',
#  'encambichado',
#  'enxodozado',
#  'camote',
#  'piranambu',
#  'pirapeua',
#  'sairu',
#  'tiravira',
#  'abraseado',
#  'apurpurado',
#  'puníceo',
#  'purpurejante',
#  'aracapuri',
#  'aruiri',
#  'chaperema',
#  'cujuba',
#  'sambuio',
#  'mucum',
#  'psichê',
#  'paparicho',
#  'refrescativo',
#  'entrepresa',
#  'blasonaria',
#  'enfunação',
#  'gabação',
#  'jatância',
#  'corrimaca',
#  'menecma',
#  'persigal',
#  'artério',
#  'ocelar',
#  'chupadouro',
#  'protegedor',
#  'tutelador',
#  'montanhesco',
#  'montaraz',
#  'muzarella',
#  'parmezon',
#  'rabadela',
#  'mp3',
#  'rambutan',
#  'alumiação',
#  'aluminação',
#  'clareação',
#  'dilucidamento',
#  'afroixamento',
#  'aloá',
#  'regalengo',
#  'casalejo',
#  'aviolado',
#  'retumbo',
#  'aforramento',
#  'venustidade',
#  'rodomoinho',
#  'saboneira',
#  'saboneteiro',
#  'celofone',
#  'escoadura',
#  'egressão',
#  'retiração',
#  'rosaça',
#  'salamalaque',
#  'zumbaia',
#  'sarolho',
#  'saxofono',
#  'schimier',
#  'ratonice',
#  'sub-repção',
#  'chegadela',
#  'esbregue',
#  'ralhação',
#  'acanavear',
#  'adelgadar',
#  'adelgar',
#  'delgaçar',
#  'desencorpar',
#  'desmedrar',
#  'desnutrir',
#  'emaciar',
#  'emagrentar',
#  'engoiar-se',
#  'entresilhar',
#  'escanifrar',
#  'estalicar',
#  'desengordar',
#  'encovar',
#  'shampu',
#  'nérveo',
#  'nervino',
#  'neurino',
#  'nevrino',
#  'sobrepasto',
#  'steinharger',
#  'fatício',
#  'adjeção',
#  'pascentar',
#  'alimental',
#  'esculento',
#  'nutrício',
#  'nutritício',
#  'sustagem',
#  'coirela',
#  'alfofre',
#  'alfovre',
#  'assadeiro',
#  'aguaritar',
#  'dessumir',
#  'eduzir',
#  'intuicionar',
#  'surpresar',
#  'garavanço',
#  'atambor',
#  'tamborino',
#  'tampadura',
#  'tapadoiro',
#  'tapadouro',
#  'descártaveis',
#  'reenvide',
#  'recâmbio',
#  'papelagem',
#  'atarefamento',
#  'quefazeres',
#  'rapinação',
#  'sazon',
#  'testáceo',
#  'mp4',
#  'mp5',
#  'tosadeira',
#  'béquico',
#  'totolec',
#  'baldaquin',
#  'balseira',
#  'atravessadoiro',
#  'atravessadouro',
#  'cambapé',
#  'gambérria',
#  'sancadilha',
#  'trimania',
#  'umbigueiro',
#  'unímodo',
#  'queimão',
#  'quimão',
#  'vagação',
#  'vagância',
#  'enxugadoiro',
#  'enxugadouro',
#  'estendedoiro',
#  'estendedouro',
#  'veladura',
#  'antiverminoso',
#  'acortinado',
#  'aditício',
#  'matral',
#  'mátrio',
#  'helmíntico',
#  'hemorragíaco',
#  'infectuoso',
#  'infetuoso',
#  'inflamativo',
#  'antianêmico',
#  'ultracansado',
#  'introverso',
#  'tabelinado',
#  'ceroma',
#  'absidado',
#  'acurvado',
#  'alcatruzado',
#  'arcual',
#  'concamerado',
#  'embodocado',
#  'transmudação',
#  'transmudamento',
#  'desintupidor',
#  'esperemedor',
#  'enxofrão',
#  'fisális',
#  'manante',
#  'apregoador',
#  'halitol',
#  'hipocolesterolêmico',
#  'hormônico',
#  'silicilato',
#  'infortuna',
#  'presentâneo',
#  'semipreparada',
#  'grilhagem',
#  'defluência',
#  'passadoiro',
#  'pirapitanga',
#  'tendenciado',
#  'inflecto',
#  'inflexo',
#  'úngula',
#  'rambutã',
#  'adormentar',
#  'adormir',
#  'soporizar',
#  'abnoitar',
#  'pernoutar',
#  'homem-feito',
#  'enviamento',
#  ...]

# %%
matriz_aux = np.zeros((300, ), dtype = "float32")
for token in tokens_nc:
    model[token] = matriz_aux

# %% [markdown]
# ## Soma de Embeddings

# %%
def embedding_soma(sentence, model, num_features, word_set):
    words = sentence.split()
    feature_vec = np.zeros((num_features, ), dtype = "float32")
    for word in words:
        if word in word_set:
            feature_vec = np.add(feature_vec, model[word])
    model[sentence] = feature_vec

# %%
word_set = set(model.index_to_key)
todas_descricoes = descricoes_pof + descricoes_snipc
contador = 0
for descricao in todas_descricoes:
    embedding_soma(descricao, model, 300, word_set)
    if contador % 10 == 0 or contador == 4592:
        print(contador / len(todas_descricoes) * 100, "%")
    contador = contador + 1
# Out:
# 0.0 %
# 0.224517287831163 %
# 0.449034575662326 %
# 0.673551863493489 %
# 0.898069151324652 %
# 1.1225864391558151 %
# 1.347103726986978 %
# 1.5716210148181409 %
# 1.796138302649304 %
# 2.020655590480467 %
# 2.2451728783116303 %
# 2.469690166142793 %
# 2.694207453973956 %
# 2.918724741805119 %
# 3.1432420296362817 %
# 3.3677593174674447 %
# 3.592276605298608 %
# 3.816793893129771 %
# 4.041311180960934 %
# 4.265828468792097 %
# 4.4903457566232605 %
# 4.7148630444544235 %
# 4.939380332285586 %
# 5.163897620116749 %
# 5.388414907947912 %
# 5.612932195779075 %
# 5.837449483610238 %
# 6.0619667714414005 %
# 6.2864840592725635 %
# 6.511001347103727 %
# 6.7355186349348894 %
# 6.960035922766053 %
# 7.184553210597216 %
# 7.409070498428378 %
# 7.633587786259542 %
# 7.858105074090704 %
# 8.082622361921867 %
# 8.307139649753031 %
# 8.531656937584193 %
# 8.756174225415357 %
# 8.980691513246521 %
# 9.205208801077683 %
# 9.429726088908847 %
# 9.654243376740009 %
# 9.878760664571171 %
# 10.103277952402335 %
# 10.327795240233497 %
# 10.552312528064661 %
# 10.776829815895823 %
# 11.001347103726987 %
# 11.22586439155815 %
# 11.450381679389313 %
# 11.674898967220477 %
# 11.899416255051639 %
# 12.123933542882801 %
# 12.348450830713965 %
# 12.572968118545127 %
# 12.79748540637629 %
# 13.022002694207455 %
# 13.246519982038619 %
# 13.471037269869779 %
# 13.695554557700943 %
# 13.920071845532107 %
# 14.144589133363269 %
# 76.2481089258699 %
# 76.55068078668684 %
# 76.85325264750378 %
# 77.15582450832072 %
# 77.45839636913767 %
# 77.76096822995461 %
# 78.06354009077155 %
# 78.36611195158851 %
# 78.66868381240545 %
# 78.9712556732224 %
# 79.27382753403933 %
# 79.57639939485628 %
# 79.87897125567322 %
# 80.18154311649016 %
# 80.48411497730712 %
# 80.78668683812406 %
# 81.08925869894101 %
# 81.39183055975793 %
# 81.69440242057489 %
# 81.99697428139183 %
# 82.29954614220878 %
# 82.60211800302571 %
# 82.90468986384266 %
# 83.2072617246596 %
# 83.50983358547656 %
# 83.8124054462935 %
# 84.11497730711044 %
# 84.41754916792739 %
# 84.72012102874432 %
# 85.02269288956127 %
# 85.32526475037821 %
# 85.62783661119516 %
# 85.9304084720121 %
# 86.23298033282904 %
# 86.535552193646 %
# 86.83812405446294 %
# 87.14069591527988 %
# 87.44326777609682 %
# 87.74583963691377 %
# 88.04841149773071 %
# 88.35098335854765 %
# 88.6535552193646 %
# 88.95612708018155 %
# 89.25869894099849 %
# 89.56127080181543 %
# 89.86384266263238 %
# 90.16641452344932 %
# 90.46898638426626 %
# 90.77155824508321 %
# 91.07413010590015 %
# 91.37670196671709 %
# 91.67927382753403 %
# 91.98184568835099 %
# 92.28441754916793 %
# 92.58698940998488 %
# 92.8895612708018 %
# 93.19213313161876 %
# 93.4947049924357 %
# 93.79727685325264 %
# 94.0998487140696 %
# 94.40242057488653 %
# 94.70499243570349 %
# 95.00756429652041 %
# 95.31013615733737 %
# 95.61270801815431 %
# 95.91527987897126 %
# 96.2178517397882 %
# 96.52042360060514 %
# 96.8229954614221 %
# 97.12556732223904 %
# 97.42813918305598 %
# 97.73071104387292 %
# 98.03328290468987 %
# 98.33585476550681 %
# 98.63842662632375 %
# 98.9409984871407 %
# 99.24357034795764 %
# 99.54614220877458 %
# 99.84871406959152 %

# %%
os.chdir(path_resultados)
df_word2vec_soma.to_excel("Word2VecSoma_TodosSinonimos_MS.xlsx")

# %% [markdown]
# ## Word2Vec Média

# %%
def embedding_media(sentence, model, num_features, word_set):
    words = sentence.split()
    n_words = 0
    feature_vec = np.zeros((num_features, ), dtype = "float32")
    for word in words:
        if word in word_set:
            feature_vec = np.add(feature_vec, model[word])
            n_words = n_words + 1
    model[sentence] = feature_vec / n_words

# %%
word_set = set(model.index_to_key)
todas_descricoes = descricoes_pof + descricoes_snipc
contador = 0
for descricao in todas_descricoes:
    embedding_media(descricao, model, 300, word_set)
    if contador % 10 == 0 or contador == 4592:
        print(contador / len(todas_descricoes) * 100, "%")
    contador = contador + 1
# Out:
# 0.0 %
# 0.224517287831163 %
# 0.449034575662326 %
# 0.673551863493489 %
# 0.898069151324652 %
# 1.1225864391558151 %
# 1.347103726986978 %
# 1.5716210148181409 %
# 1.796138302649304 %
# 2.020655590480467 %
# 2.2451728783116303 %
# 2.469690166142793 %
# 2.694207453973956 %
# 2.918724741805119 %
# 3.1432420296362817 %
# 3.3677593174674447 %
# 3.592276605298608 %
# 3.816793893129771 %
# 4.041311180960934 %
# 4.265828468792097 %
# 91.6030534351145 %
# 91.82757072294567 %
# 92.05208801077683 %
# 92.27660529860799 %
# 92.50112258643915 %
# 92.72563987427031 %
# 92.95015716210148 %
# 93.17467444993265 %
# 93.39919173776381 %
# 93.62370902559498 %
# 93.84822631342612 %
# 94.07274360125729 %
# 94.29726088908846 %
# 94.52177817691963 %
# 94.74629546475079 %
# 94.97081275258195 %
# 95.19533004041311 %
# 95.41984732824427 %
# 95.64436461607544 %
# 95.8688819039066 %
# 96.09339919173776 %
# 96.31791647956892 %
# 96.5424337674001 %
# 96.76695105523126 %
# 96.99146834306241 %
# 97.21598563089357 %
# 97.44050291872475 %
# 97.66502020655591 %
# 97.88953749438707 %
# 98.11405478221823 %
# 98.3385720700494 %
# 98.56308935788056 %
# 98.78760664571172 %
# 99.01212393354288 %
# 99.23664122137404 %
# 99.4611585092052 %
# 99.68567579703638 %
# 99.91019308486754 %

# %%
contador = 0
for palavra_pof in df_word2vec_media.index:
    for palavra_snipc in df_word2vec_media.columns:
        df_word2vec_media.at[palavra_pof, palavra_snipc] = model.similarity(palavra_pof, palavra_snipc)
    contador = contador + 1
    if contador % 10 == 0 or contador == 3376:
        print(contador / df_word2vec_media.shape[0] * 100, "%")
# Out:
# 0.30257186081694404 %
# 0.6051437216338881 %
# 0.9077155824508321 %
# 1.2102874432677762 %
# 1.5128593040847202 %
# 1.8154311649016641 %
# 2.118003025718608 %
# 2.4205748865355523 %
# 2.723146747352496 %
# 3.0257186081694405 %
# 3.3282904689863844 %
# 3.6308623298033282 %
# 3.9334341906202726 %
# 4.236006051437216 %
# 4.53857791225416 %
# 4.841149773071105 %
# 5.143721633888049 %
# 5.446293494704992 %
# 5.748865355521937 %
# 6.051437216338881 %
# 6.354009077155824 %
# 6.656580937972769 %
# 6.959152798789712 %
# 7.2617246596066565 %
# 7.564296520423601 %
# 7.866868381240545 %
# 8.169440242057489 %
# 8.472012102874432 %
# 8.774583963691377 %
# 9.07715582450832 %
# 9.379727685325264 %
# 9.68229954614221 %
# 9.984871406959153 %
# 10.287443267776098 %
# 10.59001512859304 %
# 10.892586989409985 %
# 11.195158850226928 %
# 11.497730711043873 %
# 11.800302571860817 %
# 12.102874432677762 %
# 12.405446293494705 %
# 12.708018154311649 %
# 13.010590015128592 %
# 13.313161875945537 %
# 13.61573373676248 %
# 13.918305597579424 %
# 14.22087745839637 %
# 14.523449319213313 %
# 14.826021180030258 %
# 15.128593040847202 %
# 15.431164901664147 %
# 15.73373676248109 %
# 16.036308623298034 %
# 16.338880484114977 %
# 16.64145234493192 %
# 16.944024205748864 %
# 17.246596066565807 %
# 17.549167927382754 %
# 17.851739788199698 %
# 18.15431164901664 %
# 18.456883509833585 %
# 18.759455370650528 %
# 19.062027231467475 %
# 19.36459909228442 %
# 19.667170953101362 %
# 19.969742813918305 %
# 20.272314674735252 %
# 20.574886535552196 %
# 20.87745839636914 %
# 21.18003025718608 %
# 21.482602118003026 %
# 21.78517397881997 %
# 22.087745839636913 %
# 22.390317700453856 %
# 22.692889561270803 %
# 22.995461422087747 %
# 23.29803328290469 %
