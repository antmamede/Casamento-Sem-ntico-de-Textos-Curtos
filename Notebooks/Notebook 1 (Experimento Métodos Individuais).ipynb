# %% [markdown]
# # Importando Pacotes

# %%
import os
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import nltk
import strsimpy
import numpy as np
from strsimpy.normalized_levenshtein import NormalizedLevenshtein
from strsimpy.jaro_winkler import JaroWinkler
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models import KeyedVectors

# %% [markdown]
# # Paths

# %%
path_bases = "C:\\Users\\aamma\\OneDrive\\ENCE\\TCC\\Bases"
path_embeddings = "C:\\Users\\aamma\\OneDrive\\ENCE\\TCC\\Embeddings"
path_resultados = "C:\\Users\\aamma\\OneDrive\\ENCE\\TCC\\Resultados"

# %% [markdown]
# # Leitura de Bases

# %%
os.chdir(path_bases)
descricoes_pof = pd.read_excel("Descricoes_POF.xlsx")
descricoes_snipc = pd.read_excel("Descricoes_SNIPC.xlsx")
descricoes_pof = descricoes_pof.values.tolist() # Converte dataframe para lista de listas
descricoes_snipc = descricoes_snipc.values.tolist() # Coverte dataframe para lista de listas
descricoes_pof = [item for sublist in descricoes_pof for item in sublist] # Converte lista de listas para lista
descricoes_snipc = [item for sublist in descricoes_snipc for item in sublist] # Converte lista de listas para lista

# %% [markdown]
# # Criando Matrizes de Similaridade

# %% [markdown]
# ## Separando Descrições por Pesquisa

# %% [markdown]
# ## Levenshtein

# %%
df_levenshtein = np.zeros((len(descricoes_pof), len(descricoes_snipc)))
df_levenshtein = pd.DataFrame(df_levenshtein, columns = descricoes_snipc,
index = descricoes_pof)

# %% [markdown]
# ## Jaro

# %%
df_jaro = np.zeros((len(descricoes_pof), len(descricoes_snipc)))
df_jaro = pd.DataFrame(df_jaro, columns = descricoes_snipc,
index = descricoes_pof)

# %% [markdown]
# ## Jaccard

# %%
df_jaccard = np.zeros((len(descricoes_pof), len(descricoes_snipc)))
df_jaccard = pd.DataFrame(df_jaccard, columns = descricoes_snipc,
index = descricoes_pof)

# %% [markdown]
# ## tf-idf

# %%
df_tfidf = np.zeros((len(descricoes_pof), len(descricoes_snipc)))
df_tfidf = pd.DataFrame(df_tfidf, columns = descricoes_snipc,
index = descricoes_pof)

# %% [markdown]
# ## Word2Vec

# %%
df_word2vec_soma = np.zeros((len(descricoes_pof), len(descricoes_snipc)))
df_word2vec_soma = pd.DataFrame(df_word2vec_soma, columns = descricoes_snipc,
index = descricoes_pof)
df_word2vec_media = np.zeros((len(descricoes_pof), len(descricoes_snipc)))
df_word2vec_media = pd.DataFrame(df_word2vec_media, columns = descricoes_snipc,
index = descricoes_pof)

# %% [markdown]
# # Calculando Similaridade

# %% [markdown]
# ## Levenshtein

# %%
levenshtein = NormalizedLevenshtein()
contador = 0
for palavra_pof in df_levenshtein.index:
    for palavra_snipc in df_levenshtein.columns:
        df_levenshtein.at[palavra_pof, palavra_snipc] = levenshtein.similarity(palavra_pof, palavra_snipc)
    contador = contador + 1
    if contador % 700 == 0 or contador == 3391:
        print(contador / df_levenshtein.shape[0] * 100, "%")
# Out:
# 20.642878207018576 %
# 41.28575641403715 %
# 61.928634621055735 %
# 82.5715128280743 %
# 100.0 %

# %%
path_resultados = "C:\\Users\\aamma\\OneDrive\\ENCE\\TCC\\Resultados"
os.chdir(path_resultados)
df_levenshtein.to_excel("Levenshtein_MS.xlsx")

# %% [markdown]
# ## Jaro

# %%
jaro = JaroWinkler()
contador = 0
for palavra_pof in df_jaro.index:
    for palavra_snipc in df_jaro.columns:
        df_jaro.at[palavra_pof, palavra_snipc] = jaro.similarity(palavra_pof, palavra_snipc)
    contador = contador + 1
    if contador % 700 == 0 or contador == 3391:
        print(contador / df_jaro.shape[0] * 100, "%")
# Out:
# 20.642878207018576 %
# 41.28575641403715 %
# 61.928634621055735 %
# 82.5715128280743 %
# 100.0 %

# %%
os.chdir(path_resultados)
df_jaro.to_excel("Jaro_MS.xlsx")

# %% [markdown]
# ## Jaccard

# %%
contador = 0
for palavra_pof in df_jaccard.index:
    for palavra_snipc in df_jaccard.columns:
        tok_pof = set(palavra_pof.split())
        tok_snipc = set(palavra_snipc.split())
        numerador = tok_pof & tok_snipc
        denominador = tok_pof | tok_snipc
        df_jaccard.at[palavra_pof, palavra_snipc] = len(numerador) / len(denominador)
    contador = contador + 1
    if contador % 700 == 0 or contador == 3391:
        print(contador / df_jaccard.shape[0] * 100, "%")
# Out:
# 20.642878207018576 %
# 41.28575641403715 %
# 61.928634621055735 %
# 82.5715128280743 %
# 100.0 %

# %%
os.chdir(path_resultados)
df_jaccard.to_excel("Jaccard_MS.xlsx")

# %% [markdown]
# ## TF-IDF

# %%
vectorizer = TfidfVectorizer()

# Juntando Todas as Descrições e Removendo duplicatas
todas_descricoes = descricoes_pof + descricoes_snipc
todas_descricoes = pd.Series(todas_descricoes).drop_duplicates().to_list()

# Calculando valores TF-IDF
tfidf_matrix = vectorizer.fit_transform(todas_descricoes)

# Transformando Matriz TF-IDF em DF
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), index=todas_descricoes, columns=vectorizer.get_feature_names_out())

# Filtrando por pesquisas
tfidf_snipc = tfidf_df.filter(items = descricoes_snipc, axis = 0)
tfidf_pof = tfidf_df.filter(items = descricoes_pof, axis = 0)

## Calculando Cosseno e transformando em DF
cosine_sim = cosine_similarity(tfidf_pof, tfidf_snipc)
df_tfidf = pd.DataFrame(cosine_sim, index = descricoes_pof, columns = descricoes_snipc)

# %%
os.chdir(path_resultados)
df_tfidf.to_excel("TFIDF_MS.xlsx")

# %% [markdown]
# ## Word2Vec

# %% [markdown]
# ### Lendo Embeddings

# %%
os.chdir(path_embeddings)
os.getcwd()
model = KeyedVectors.load_word2vec_format("skip_s300.txt")

# Testando base nova (sem sentencas de palavras unicas nao contidas nos embeddings)
os.chdir(path_bases)
descricoes_pof = pd.read_excel("Descricoes_POF_CE.xlsx")
descricoes_snipc = pd.read_excel("Descricoes_SNIPC_CE.xlsx")
descricoes_pof = descricoes_pof.values.tolist() # Converte dataframe para lista de listas
descricoes_snipc = descricoes_snipc.values.tolist() # Coverte dataframe para lista de listas
descricoes_pof = [item for sublist in descricoes_pof for item in sublist] # Converte lista de listas para lista
descricoes_snipc = [item for sublist in descricoes_snipc for item in sublist] # Converte lista de listas para lista

# %%
tokens_all = pd.read_excel("Tokens_All_CE.xlsx")
tokens_all = tokens_all.values.tolist()
tokens_all = [item for sublist in tokens_all for item in sublist]
vocab_set = set(model.index_to_key)
keep_set = set(tokens_all)
drop_set = vocab_set - keep_set
for word in drop_set:
    del model.key_to_index[word]
model.save_word2vec_format("testando_emb.txt", binary=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 os.chdir(path_bases)
#       3 tokens_all = pd.read_excel("Tokens_All.xlsx")
#       4 tokens_all = tokens_all.values.tolist()
#
# NameError: name 'os' is not defined

# %%
model["samurai"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 model["samurai"]
#
# File E:\miniconda3\envs\tcc\lib\site-packages\gensim\models\keyedvectors.py:395, in KeyedVectors.__getitem__(self, key_or_keys)
#     381 """Get vector representation of `key_or_keys`.
#     382
#     383 Parameters
#    (...)
#     392
#     393 """
#     394 if isinstance(key_or_keys, _KEY_TYPES):
# --> 395     return self.get_vector(key_or_keys)
#     397 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File E:\miniconda3\envs\tcc\lib\site-packages\gensim\models\keyedvectors.py:438, in KeyedVectors.get_vector(self, key, norm)
#     414 def get_vector(self, key, norm=False):
#     415     """Get the key's vector, as a 1D numpy array.
#     416
#     417     Parameters
#    (...)
#     436
#     437     """
# --> 438     index = self.get_index(key)
#     439     if norm:
#     440         self.fill_norms()
#
# File E:\miniconda3\envs\tcc\lib\site-packages\gensim\models\keyedvectors.py:412, in KeyedVectors.get_index(self, key, default)
#     410     return default
#     411 else:
# --> 412     raise KeyError(f"Key '{key}' not present")
#
# KeyError: "Key 'samurai' not present"

# %% [markdown]
# ### Word2Vec Soma

# %%
def embedding_soma(string):
    palavras = string.split()
    palavras = [item for item in palavras if item in model] # remove palavras não contidas no modelo note que seguindo dessa forma a sentenca "samurai caxaco" vai ter o mesmo embedding que "samurai" pois "caxaco" nao está contido no embedding
    resultado = sum([model[palavra] for palavra in palavras])
    return resultado

# %% [markdown]
# ## Cria Embeddings das Sentenças por Soma

# %%
def embedding_soma(sentence, model, num_features, word_set):
    words = sentence.split()
    feature_vec = np.zeros((num_features, ), dtype = "float32")
    for word in words:
        if word in word_set:
            feature_vec = np.add(feature_vec, model[word])
    model[sentence] = feature_vec

# %%
word_set = set(model.index_to_key)
todas_descricoes = descricoes_pof + descricoes_snipc
contador = 0
for descricao in todas_descricoes:
    embedding_soma(descricao, model, 300, word_set)
    if contador % 10 == 0 or contador == 4592:
        print(contador / len(todas_descricoes) * 100, "%")
    contador = contador + 1
# Out:
# 0.0 %
# 0.21777003484320556 %
# 0.4355400696864111 %
# 0.6533101045296167 %
# 0.8710801393728222 %
# 1.088850174216028 %
# 1.3066202090592334 %
# 1.524390243902439 %
# 1.7421602787456445 %
# 1.95993031358885 %
# 2.177700348432056 %
# 2.3954703832752613 %
# 2.6132404181184667 %
# 2.8310104529616726 %
# 86.0191637630662 %
# 86.23693379790942 %
# 86.45470383275261 %
# 86.67247386759583 %
# 86.89024390243902 %
# 87.10801393728222 %
# 87.32578397212544 %
# 87.54355400696863 %
# 87.76132404181185 %
# 87.97909407665504 %
# 88.19686411149826 %
# 88.41463414634147 %
# 88.63240418118467 %
# 88.85017421602788 %
# 89.06794425087108 %
# 89.28571428571429 %
# 89.50348432055749 %
# 89.72125435540069 %
# 89.9390243902439 %
# 90.1567944250871 %
# 90.37456445993031 %
# 90.59233449477352 %
# 90.81010452961672 %
# 91.02787456445994 %
# 91.24564459930313 %
# 91.46341463414635 %
# 91.68118466898954 %
# 91.89895470383276 %
# 92.11672473867596 %
# 92.33449477351915 %
# 92.55226480836237 %
# 92.77003484320558 %
# 92.98780487804879 %
# 93.20557491289199 %
# 93.42334494773519 %
# 93.6411149825784 %
# 93.8588850174216 %
# 94.07665505226481 %
# 94.29442508710801 %
# 94.51219512195121 %
# 94.72996515679442 %
# 94.94773519163763 %
# 95.16550522648085 %
# 95.38327526132404 %
# 95.60104529616724 %
# 95.81881533101046 %
# 96.03658536585365 %
# 96.25435540069687 %
# 96.47212543554006 %
# 96.68989547038328 %
# 96.90766550522648 %
# 97.12543554006969 %
# 97.3432055749129 %
# 97.5609756097561 %
# 97.77874564459931 %
# 97.99651567944251 %
# 98.21428571428571 %
# 98.43205574912892 %
# 98.64982578397212 %
# 98.86759581881533 %
# 99.08536585365853 %
# 99.30313588850174 %
# 99.52090592334496 %
# 99.73867595818815 %
# 99.95644599303137 %

# %%
df_word2vec_soma.columns
# Out:
# Index(['abóbora', 'abóbora d água', 'abóbora moranga', 'abobrinha',
#        'absorvente higiênico', 'açaí emulsão', 'acendedor fogão',
#        'acesso internet', 'acessórios impressora',
#        'acessórios máquina fotográfica',
#        ...
#        'vinagre maçã', 'vinho', 'vinho orgânico', 'víscera carneiro',
#        'víscera porco', 'vitamina fortificante', 'wasabi', 'windsurfe',
#        'xampu carpete', 'xampu veículo'],
#       dtype='object', length=1216)

# %%
contador = 0
for palavra_pof in df_word2vec_soma.index:
    for palavra_snipc in df_word2vec_soma.columns:
        df_word2vec_soma.at[palavra_pof, palavra_snipc] = model.similarity(palavra_pof, palavra_snipc)
    contador = contador + 1
    if contador % 10 == 0 or contador == 3376:
        print(contador / df_word2vec_soma.shape[0] * 100, "%")
# Out:
# 0.2962085308056872 %
# 0.5924170616113744 %
# 0.8886255924170616 %
# 1.1848341232227488 %
# 1.481042654028436 %
# 1.7772511848341233 %
# 2.0734597156398102 %
# 2.3696682464454977 %
# 2.665876777251185 %
# 2.962085308056872 %
# 3.2582938388625595 %
# 3.5545023696682465 %
# 3.850710900473934 %
# 4.1469194312796205 %
# 4.443127962085308 %
# 4.739336492890995 %
# 5.035545023696683 %
# 5.33175355450237 %
# 5.627962085308057 %
# 5.924170616113744 %
# 6.220379146919431 %
# 6.516587677725119 %
# 6.812796208530806 %
# 7.109004739336493 %
# 7.4052132701421804 %
# 7.701421800947868 %
# 83.23459715639811 %
# 83.5308056872038 %
# 83.82701421800948 %
# 84.12322274881517 %
# 84.41943127962085 %
# 84.71563981042654 %
# 85.01184834123224 %
# 85.30805687203792 %
# 85.60426540284361 %
# 85.9004739336493 %
# 86.19668246445498 %
# 86.49289099526067 %
# 86.78909952606635 %
# 87.08530805687204 %
# 87.38151658767772 %
# 87.67772511848341 %
# 87.97393364928911 %
# 88.2701421800948 %
# 88.56635071090048 %
# 88.86255924170617 %
# 89.15876777251185 %
# 89.45497630331754 %
# 89.75118483412322 %
# 90.04739336492891 %
# 90.3436018957346 %
# 90.63981042654028 %
# 90.93601895734598 %
# 91.23222748815166 %
# 91.52843601895735 %
# 91.82464454976304 %
# 92.12085308056872 %
# 92.41706161137441 %
# 92.7132701421801 %
# 93.00947867298578 %
# 93.30568720379146 %
# 93.60189573459715 %
# 93.89810426540285 %
# 94.19431279620854 %
# 94.49052132701422 %
# 94.7867298578199 %
# 95.08293838862559 %
# 95.37914691943128 %
# 95.67535545023696 %
# 95.97156398104265 %
# 96.26777251184834 %
# 96.56398104265402 %
# 96.86018957345972 %
# 97.1563981042654 %
# 97.45260663507109 %
# 97.74881516587678 %
# 98.04502369668246 %
# 98.34123222748815 %
# 98.63744075829383 %
# 98.93364928909952 %
# 99.2298578199052 %
# 99.52606635071089 %
# 99.82227488151659 %
# 100.0 %

# %%
os.chdir(path_resultados)
df_word2vec_soma.to_excel("Word2VecSoma_MS.xlsx")

# %%
model.similarity("abóbora cabotian", "acesso internet")
# Out:
# -0.0394747

# %%
contador = 0
for palavra_pof in df_word2vec_soma.index:
    soma_pof = embedding_soma(palavra_pof)
    model[palavra_pof] = soma_pof # Se uma palavra de uma sentenca nao esta contida no embedding, mantemos ela mas ela nao altera a soma
    for palavra_snipc in df_word2vec_soma.columns:
        soma_snipc = embedding_soma(palavra_snipc)
        model[palavra_snipc] = soma_snipc
        df_word2vec_soma.at[palavra_pof, palavra_snipc] = model.similarity(palavra_pof, palavra_snipc)
    contador = contador + 1
    if contador % 700 == 0 or contador == 3391:
        print(contador / df_word2vec_soma.shape[0] * 100, "%")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [51], in <cell line: 2>()
#       5 for palavra_snipc in df_word2vec_soma.columns:
#       6     soma_snipc = embedding_soma(palavra_snipc)
# ----> 7     model[palavra_snipc] = soma_snipc
#       8     df_word2vec_soma.at[palavra_pof, palavra_snipc] = model.similarity(palavra_pof, palavra_snipc)
#       9 contador = contador + 1
#
# File E:\miniconda3\envs\tcc\lib\site-packages\gensim\models\keyedvectors.py:562, in KeyedVectors.__setitem__(self, keys, weights)
#     559     keys = [keys]
#     560     weights = weights.reshape(1, -1)
# --> 562 self.add_vectors(keys, weights, replace=True)
#
# File E:\miniconda3\envs\tcc\lib\site-packages\gensim\models\keyedvectors.py:532, in KeyedVectors.add_vectors(self, keys, weights, extras, replace)
#     529     self.index_to_key.append(key)
#     531 # add vectors, extras for new entities
# --> 532 self.vectors = vstack((self.vectors, weights[~in_vocab_mask].astype(self.vectors.dtype)))
#     533 for attr, extra in extras:
#     534     self.expandos[attr] = np.vstack((self.expandos[attr], extra[~in_vocab_mask]))
#
# File <__array_function__ internals>:5, in vstack(*args, **kwargs)
#
# File E:\miniconda3\envs\tcc\lib\site-packages\numpy\core\shape_base.py:282, in vstack(tup)
#     280 if not isinstance(arrs, list):
#     281     arrs = [arrs]
# --> 282 return _nx.concatenate(arrs, 0)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
contador = 0
for palavra_pof in df_word2vec_soma.index:
    soma_pof = embedding_soma(palavra_pof)
    model[palavra_pof] = soma_pof # Se uma palavra de uma sentenca nao esta contida no embedding, mantemos ela mas ela nao altera a soma
    for palavra_snipc in df_word2vec_soma.columns:
        soma_snipc = embedding_soma(palavra_snipc)
        model[palavra_snipc] = soma_snipc
        df_word2vec_soma.at[palavra_pof, palavra_snipc] = model.similarity(palavra_pof, palavra_snipc)
    contador = contador + 1
    if contador % 700 == 0 or contador == 3391:
        print(contador / df_word2vec_soma.shape[0] * 100, "%")

# %%
for index, row in df_word2vec_soma.iterrows():
    soma_pof = embedding_soma(index)
    soma_snipc

# %%
i = 0
for index, row in df_word2vec_soma.iterrows():
    print(row.index)
# Out:
# array([ 0.176912,  0.15762 ,  0.10616 ,  0.546431,  0.366537, -0.014038,
#        -0.15314 ,  0.153705,  0.175341, -0.381698, -0.05135 , -0.093753,
#        -0.113221,  0.360536,  0.178126,  0.219126,  0.082147,  0.358772,
#        -0.336903, -0.253408, -0.027332, -0.318542, -0.176809,  0.20854 ,
#        -0.021603,  0.198546,  0.150315,  0.308164,  0.315833, -0.320132,
#         0.249261,  0.026871, -0.633253,  0.058548,  0.220274, -0.066906,
#         0.359219, -0.417362, -0.314825, -0.207338,  0.018806,  0.103853,
#         0.166398,  0.171834, -0.035437,  0.012877,  0.349015, -0.310928,
#         0.488949,  0.18013 , -0.195094, -0.490868, -0.032826, -0.055094,
#        -0.281857,  0.032413,  0.066699,  0.367216, -0.212529, -0.025361,
#         0.058342, -0.144595, -0.151717, -0.126274, -0.284667, -0.020377,
#        -0.273635,  0.21694 ,  0.080277,  0.028561,  0.34737 ,  0.051262,
#         0.037115, -0.274287, -0.072886,  0.028719, -0.174581,  0.264425,
#         0.012051,  0.00577 ,  0.652825, -0.126999, -0.004317,  0.043325,
#        -0.019079, -0.110806,  0.338493,  0.092893,  0.04502 , -0.164748,
#         0.034103, -0.148998,  0.060781, -0.1508  ,  0.141008,  0.189568,
#         0.09203 , -0.024912, -0.293416,  0.185567,  0.006063,  0.028629,
#        -0.171437,  0.144995, -0.184582,  0.049623, -0.014725, -0.087513,
#         0.192056, -0.319154, -0.125783,  0.406448, -0.1218  ,  0.137483,
#        -0.077918, -0.177698,  0.1047  , -0.102277,  0.126812, -0.038054,
#        -0.119892, -0.092015, -0.220924,  0.264168,  0.031105, -0.092714,
#         0.19954 , -0.169294, -0.270304, -0.126329, -0.110758,  0.328086,
#         0.067128, -0.210102,  0.175563, -0.260813,  0.08676 , -0.170723,
#        -0.020651,  0.049609,  0.282143,  0.169219, -0.08909 ,  0.134769,
#        -0.342987,  0.159299, -0.215578, -0.004778,  0.058863,  0.090741,
#        -0.071812,  0.142195, -0.090523,  0.283858,  0.05482 ,  0.022605,
#        -0.136042, -0.281233,  0.353648, -0.38052 , -0.304791,  0.022174,
#        -0.084217, -0.161505, -0.351462, -0.068196, -0.108761, -0.265197,
#        -0.014189, -0.079749,  0.125428,  0.270425,  0.291243,  0.226869,
#        -0.014691, -0.073006, -0.048869,  0.225596,  0.227892,  0.160961,
#         0.169497, -0.002055,  0.09808 , -0.123486,  0.413712, -0.27432 ,
#         0.052408, -0.135203,  0.157531, -0.121268, -0.161081,  0.226738,
#        -0.08555 , -0.304407,  0.02794 ,  0.48627 , -0.028365, -0.122811,
#         0.208551, -0.046782,  0.063603, -0.206922, -0.233075, -0.087102,
#         0.166367,  0.078438,  0.335006, -0.196208,  0.099044,  0.20509 ,
#         0.104641,  0.151581, -0.317977, -0.108994,  0.056543, -0.169312,
#         0.048438,  0.000819,  0.189664, -0.13186 , -0.081173,  0.043033,
#        -0.013072, -0.1317  ,  0.08012 ,  0.287632, -0.075433,  0.097272,
#         0.310874,  0.17617 , -0.225401,  0.151315, -0.022495, -0.25752 ,
#         0.313027,  0.340711,  0.267981,  0.255605,  0.183337,  0.045422,
#        -0.032319, -0.120551, -0.408609, -0.018413,  0.267643, -0.008801,
#         0.0967  ,  0.032742, -0.319909, -0.035911,  0.21469 , -0.024905,
#        -0.256232,  0.09115 ,  0.007279, -0.538759,  0.188288,  0.050968,
#         0.296469,  0.356904,  0.290394, -0.11933 , -0.294399, -0.514761,
#         0.202   , -0.226059,  0.222638,  0.147451,  0.162758, -0.32153 ,
#        -0.063668, -0.418695,  0.115185,  0.332408, -0.006621, -0.099536,
#         0.119978,  0.251383,  0.51682 ,  0.337507,  0.044678, -0.14642 ,
#        -0.225175,  0.243893,  0.13144 ,  0.080338, -0.160474,  0.340949,
#        -0.239104,  0.025509, -0.023056, -0.101812, -0.125013, -0.066932,
#        -0.133046,  0.128428, -0.030423, -0.267167,  0.39908 ,  0.198214],
#       dtype=float32)

# %%
df_word2vec_soma["teste"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\miniconda3\envs\tcc\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File E:\miniconda3\envs\tcc\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File E:\miniconda3\envs\tcc\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'teste'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [72], in <cell line: 1>()
# ----> 1 df_word2vec_soma["teste"]
#
# File E:\miniconda3\envs\tcc\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File E:\miniconda3\envs\tcc\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'teste'

# %%
model["antianêmico"] #problema em antianemico pois essa palavra nao está contida e está sozinha, diferente de "samurai caxaco"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 model["antianêmico"]
#
# File E:\miniconda3\envs\tcc\lib\site-packages\gensim\models\keyedvectors.py:395, in KeyedVectors.__getitem__(self, key_or_keys)
#     381 """Get vector representation of `key_or_keys`.
#     382
#     383 Parameters
#    (...)
#     392
#     393 """
#     394 if isinstance(key_or_keys, _KEY_TYPES):
# --> 395     return self.get_vector(key_or_keys)
#     397 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File E:\miniconda3\envs\tcc\lib\site-packages\gensim\models\keyedvectors.py:438, in KeyedVectors.get_vector(self, key, norm)
#     414 def get_vector(self, key, norm=False):
#     415     """Get the key's vector, as a 1D numpy array.
#     416
#     417     Parameters
#    (...)
#     436
#     437     """
# --> 438     index = self.get_index(key)
#     439     if norm:
#     440         self.fill_norms()
#
# File E:\miniconda3\envs\tcc\lib\site-packages\gensim\models\keyedvectors.py:412, in KeyedVectors.get_index(self, key, default)
#     410     return default
#     411 else:
# --> 412     raise KeyError(f"Key '{key}' not present")
#
# KeyError: "Key 'antianêmico' not present"

# %%
os.chdir(path_resultados)
df_word2vec_soma.to_excel("W2V_Soma_MS.xlsx")

# %% [markdown]
# ### Word2Vec Média

# %%
# deleta
def embedding_media(string):
    palavras = string.split()
    n_palavras = len(palavras)
    soma = sum([model[palavra] for palavra in palavras])
    resultado = soma / n_palavras
    return resultado

# %%
# versao nova
def embedding_media(sentence, model, num_features, word_set):
    words = sentence.split()
    n_words = 0
    feature_vec = np.zeros((num_features, ), dtype = "float32")
    for word in words:
        if word in word_set:
            feature_vec = np.add(feature_vec, model[word])
            n_words = n_words + 1
    model[sentence] = feature_vec / n_words

# %%
embedding_media("abóbora branca", model, 300, set(model.index_to_key))

# %%
model["abóbora branca"] == (model["abóbora"] + model["branca"])/2
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
# versao nova
word_set = set(model.index_to_key)
todas_descricoes = descricoes_pof + descricoes_snipc
contador = 0
for descricao in todas_descricoes:
    embedding_media(descricao, model, 300, word_set)
    if contador % 10 == 0 or contador == 4592:
        print(contador / len(todas_descricoes) * 100, "%")
    contador = contador + 1
# Out:
# 0.0 %
# 0.21777003484320556 %
# 0.4355400696864111 %
# 0.6533101045296167 %
# 0.8710801393728222 %
# 1.088850174216028 %
# 1.3066202090592334 %
# 1.524390243902439 %
# 1.7421602787456445 %
# 1.95993031358885 %
# 2.177700348432056 %
# 2.3954703832752613 %
# 2.6132404181184667 %
# 2.8310104529616726 %
# 3.048780487804878 %
# 3.266550522648084 %
# 3.484320557491289 %
# 3.702090592334495 %
# 3.9198606271777 %
# 4.137630662020906 %
# 4.355400696864112 %
# 4.573170731707317 %
# 4.790940766550523 %
# 5.008710801393728 %
# 5.2264808362369335 %
# 5.444250871080139 %
# 5.662020905923345 %
# 5.879790940766551 %
# 6.097560975609756 %
# 6.315331010452961 %
# 6.533101045296168 %
# 6.7508710801393725 %
# 6.968641114982578 %
# 7.186411149825784 %
# 7.40418118466899 %
# 7.621951219512195 %
# 7.8397212543554 %
# 8.057491289198607 %
# 8.275261324041812 %
# 8.493031358885016 %
# 8.710801393728223 %
# 8.928571428571429 %
# 9.146341463414634 %
# 9.36411149825784 %
# 9.581881533101045 %
# 9.79965156794425 %
# 10.017421602787456 %
# 10.235191637630663 %
# 10.452961672473867 %
# 10.670731707317072 %
# 10.888501742160278 %
# 11.106271777003485 %
# 11.32404181184669 %
# 11.541811846689894 %
# 11.759581881533101 %
# 94.94773519163763 %
# 95.16550522648085 %
# 95.38327526132404 %
# 95.60104529616724 %
# 95.81881533101046 %
# 96.03658536585365 %
# 96.25435540069687 %
# 96.47212543554006 %
# 96.68989547038328 %
# 96.90766550522648 %
# 97.12543554006969 %
# 97.3432055749129 %
# 97.5609756097561 %
# 97.77874564459931 %
# 97.99651567944251 %
# 98.21428571428571 %
# 98.43205574912892 %
# 98.64982578397212 %
# 98.86759581881533 %
# 99.08536585365853 %
# 99.30313588850174 %
# 99.52090592334496 %
# 99.73867595818815 %
# 99.95644599303137 %

# %%
contador = 0
for palavra_pof in df_word2vec_media.index:
    for palavra_snipc in df_word2vec_media.columns:
        df_word2vec_media.at[palavra_pof, palavra_snipc] = model.similarity(palavra_pof, palavra_snipc)
    contador = contador + 1
    if contador % 10 == 0 or contador == 3376:
        print(contador / df_word2vec_media.shape[0] * 100, "%")
# Out:
# 0.2962085308056872 %
# 0.5924170616113744 %
# 0.8886255924170616 %
# 1.1848341232227488 %
# 1.481042654028436 %
# 1.7772511848341233 %
# 2.0734597156398102 %
# 2.3696682464454977 %
# 2.665876777251185 %
# 2.962085308056872 %
# 3.2582938388625595 %
# 3.5545023696682465 %
# 3.850710900473934 %
# 4.1469194312796205 %
# 4.443127962085308 %
# 4.739336492890995 %
# 5.035545023696683 %
# 5.33175355450237 %
# 5.627962085308057 %
# 5.924170616113744 %
# 6.220379146919431 %
# 6.516587677725119 %
# 6.812796208530806 %
# 7.109004739336493 %
# 7.4052132701421804 %
# 7.701421800947868 %
# 7.9976303317535535 %
# 8.293838862559241 %
# 8.590047393364928 %
# 8.886255924170616 %
# 9.182464454976303 %
# 9.47867298578199 %
# 9.774881516587678 %
# 10.071090047393366 %
# 10.367298578199053 %
# 10.66350710900474 %
# 10.959715639810426 %
# 11.255924170616113 %
# 11.552132701421801 %
# 11.848341232227488 %
# 12.144549763033176 %
# 12.440758293838861 %
# 12.736966824644549 %
# 13.033175355450238 %
# 13.329383886255924 %
# 13.625592417061611 %
# 13.921800947867299 %
# 14.218009478672986 %
# 14.514218009478675 %
# 14.810426540284361 %
# 15.106635071090047 %
# 15.402843601895736 %
# 15.699052132701421 %
# 15.995260663507107 %
# 16.291469194312796 %
# 16.587677725118482 %
# 16.88388625592417 %
# 17.180094786729857 %
# 17.476303317535542 %
# 17.77251184834123 %
# 18.068720379146917 %
# 18.364928909952607 %
# 18.661137440758292 %
# 18.95734597156398 %
# 19.253554502369667 %
# 19.549763033175356 %
# 19.845971563981042 %
# 20.14218009478673 %
# 20.438388625592417 %
# 20.734597156398106 %
# 21.03080568720379 %
# 21.32701421800948 %
# 21.623222748815166 %
# 21.919431279620852 %
# 22.21563981042654 %
# 22.511848341232227 %
# 22.808056872037916 %
# 23.104265402843602 %
# 23.400473933649288 %
# 23.696682464454977 %
# 23.992890995260662 %
# 24.28909952606635 %
# 24.585308056872037 %
# 24.881516587677723 %
# 25.177725118483412 %
# 25.473933649289098 %
# 25.770142180094783 %
# 26.066350710900476 %
